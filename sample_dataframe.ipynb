# %%
import csv
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
wine_data = pd.read_csv("Resources/winemag-data-130k-v2.csv")

sample_df=wine_data.sample(n=1000)
sample_df.head()
# Out:
#         Unnamed: 0 country                                        description  \
# 122979      122979      US  A soft, nicely oaked Merlot with flavors of ba...
# 93429        93429   Italy  This is a beautiful sparkler with outstanding ...
# 43600        43600   Italy  Linear, silky and long, this has ethereal tone...
# 66365        66365      US  Northern Italian red grapes don't often turn u...
# 99742        99742      US  This deep-colored, rich-tasting and thick-text...
#
#                      designation  points  price    province  \
# 122979                    Estate      86   24.0  California
# 93429                   Cartizze      90   35.0      Veneto
# 43600                        NaN      89    NaN    Piedmont
# 66365   Private Reserve Nebbiolo      88   25.0    Virginia
# 99742                Proprietary      89   32.0  California
#
#                               region_1          region_2         taster_name  \
# 122979              Santa Clara Valley     Central Coast      Virginie Boone
# 93429   Prosecco Superiore di Cartizze               NaN                 NaN
# 43600                       Barbaresco               NaN                 NaN
# 66365                         Virginia               NaN  Alexander Peartree
# 99742                       California  California Other          Jim Gordon
#
#        taster_twitter_handle  \
# 122979               @vboone
# 93429                    NaN
# 43600                    NaN
# 66365                    NaN
# 99742       @gordone_cellars
#
#                                                     title    variety  \
# 122979  Jason-Stephens 2009 Estate Merlot (Santa Clara...     Merlot
# 93429   Bortolomiol 2006 Cartizze  (Prosecco Superiore...   Prosecco
# 43600                      Ca' du Rabajà 2009  Barbaresco   Nebbiolo
# 66365   Horton 2014 Private Reserve Nebbiolo Rosé (Vir...       Rosé
# 99742           Foundry 2012 Proprietary Red (California)  Red Blend
#
#                 winery
# 122979  Jason-Stephens
# 93429      Bortolomiol
# 43600    Ca' du Rabajà
# 66365           Horton
# 99742          Foundry
